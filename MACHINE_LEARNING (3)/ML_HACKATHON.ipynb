# %% [markdown]
# ##### Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# to display all rows and columns...
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# # PART 1

# %% [markdown]
# ## TASK 1

# %%
# data
df = pd.read_csv("house_data.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
list(df.columns)
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %% [markdown]
# ## TASK 2

# %%
# fitering the dataset and creating a new DataFrame as per requirement(selected columns)...
df_subset1 = df.loc[[i for i in range(0,1460)],['SalePrice',
                                              'GrLivArea',
                                              'LotArea',
                                              'GarageArea',
                                              'GarageCars',
                                              'FullBath',
                                              'YearBuilt',
                                              'YrSold']]
df_subset1
# Out:
#       SalePrice  GrLivArea  LotArea  GarageArea  GarageCars  FullBath  \
# 0        208500       1710     8450         548           2         2
# 1        181500       1262     9600         460           2         2
# 2        223500       1786    11250         608           2         2
# 3        140000       1717     9550         642           3         1
# 4        250000       2198    14260         836           3         2
# ...         ...        ...      ...         ...         ...       ...
# 1455     175000       1647     7917         460           2         2
# 1456     210000       2073    13175         500           2         2
# 1457     266500       2340     9042         252           1         2
# 1458     142125       1078     9717         240           1         1
# 1459     147500       1256     9937         276           1         1
#
#       YearBuilt  YrSold
# 0          2003    2008
# 1          1976    2007
# 2          2001    2008
# 3          1915    2006
# ...

# %%
# Adding a column in the subset_DataFrame named "AgeWhenSold" by substracting the YearSold - YearBuild...resulting in Age of...
df_subset1["AgeWhenSold"] = df_subset1["YrSold"] - df_subset1["YearBuilt"]
df_subset1
# Out:
#       SalePrice  GrLivArea  LotArea  GarageArea  GarageCars  FullBath  \
# 0        208500       1710     8450         548           2         2
# 1        181500       1262     9600         460           2         2
# 2        223500       1786    11250         608           2         2
# 3        140000       1717     9550         642           3         1
# 4        250000       2198    14260         836           3         2
# ...         ...        ...      ...         ...         ...       ...
# 1455     175000       1647     7917         460           2         2
# 1456     210000       2073    13175         500           2         2
# 1457     266500       2340     9042         252           1         2
# 1458     142125       1078     9717         240           1         1
# 1459     147500       1256     9937         276           1         1
#
#       YearBuilt  YrSold  AgeWhenSold
# 0          2003    2008            5
# 1          1976    2007           31
# ...

# %% [markdown]
# ## TASK 3

# %%
df_subset1 = df_subset1[(df_subset1.LotArea<= 40000) & (df_subset1.GrLivArea<= 2600)]
df_subset1
# Out:
#       SalePrice  GrLivArea  LotArea  GarageArea  GarageCars  FullBath  \
# 0        208500       1710     8450         548           2         2
# 1        181500       1262     9600         460           2         2
# 2        223500       1786    11250         608           2         2
# 3        140000       1717     9550         642           3         1
# 4        250000       2198    14260         836           3         2
# ...         ...        ...      ...         ...         ...       ...
# 1455     175000       1647     7917         460           2         2
# 1456     210000       2073    13175         500           2         2
# 1457     266500       2340     9042         252           1         2
# 1458     142125       1078     9717         240           1         1
# 1459     147500       1256     9937         276           1         1
#
#       YearBuilt  YrSold  AgeWhenSold
# 0          2003    2008            5
# 1          1976    2007           31
# ...

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # PART 2

# %% [markdown]
# ## TASK 1

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_subset1["GrLivArea"]
y = df_subset1["SalePrice"]

# %%
df_subset1.plot(kind='scatter', x='GrLivArea', y='SalePrice', figsize=(10, 5))
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
#sns.scatterplot(x="GrLivArea", y="SalePrice", data=df_subset1)

# %%
sns.regplot(x="GrLivArea", y="SalePrice", data=df_subset1)
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
X_train,X_test,y_train,y_test = train_test_split(X,
                                                 y, 
                                                 test_size= 0.2, 
                                                 random_state = 101)

# %% [markdown]
# ## TASK 2/3/4

# %% [markdown]
# ## Creating a Model (Estimator)
# ##### Import a model class from a model family

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# * Create an instance of the model with Parameters

# %% [markdown]
# ## Fit / Train the model on the training dataset

# %%
model = LinearRegression()

# %% [markdown]
# if!
#
# VALUEERROR: Expected 2D array, got 1D array instead:
# array=[1285 1954  848 ... 2080 1252 1063].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# So convert it to numpy array...like in cell below

# %%
X = np.array(df_subset1['GrLivArea']).reshape(-1,1)
y = np.array(df_subset1['SalePrice']).reshape(-1,1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,
                                                 y, 
                                                 test_size= 0.2, 
                                                 random_state = 101)

# %%
y_pred = model.predict(X_test)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[108.28600851]])

# %% [markdown]
# ## Understanding and Utilizing the model
# ##### Evaluation on the test dataset

# %%
test_predictions = model.predict(X_test)
test_predictions
# Out:
# array([[234141.06322754],
#        [241396.22579783],
#        [258288.84312567],
#        [164513.15975446],
#        [200247.54256335],
#        [151843.69675858],
#        [169277.74412898],
#        [170793.74824814],
#        [128778.77694556],
#        [120657.32630718],
#        [118816.46416248],
#        [201222.11663996],
#        [188119.50961003],
#        [161697.72353315],
#        [114376.7378135 ],
#        [173392.61245243],
#        [110911.58554112],
#        [209560.13929537],
#        [216273.8718231 ],
#        [189743.79973771],
#        [179240.05691206],
#        [146104.53830745],
#        [229376.47885302],
#        [186386.93347384],
#        [215191.01173798],
#        [136791.94157544],
#        [186820.07750789],
#        [289042.06954302],
#        [163971.7297119 ],
#        [205878.41500596],
#        [196349.24625693],
#        [281678.62096422],
#        [109720.43944749],
#        [234790.77927861],
#        [117083.88802629],
# ...

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,roc_curve,roc_auc_score

# %%
MAE = mean_absolute_error(y_test, test_predictions)
MSE = mean_squared_error(y_test, test_predictions)
RMSE = np.sqrt(MSE)

# %%
#Mean Absolute Error
MAE
# Out:
# 30759.80998552548

# %%
#Mean Squared Error
MSE
# Out:
# 1895721342.0373652

# %%
#Root Mean Squared Error
RMSE
# Out:
# 43539.88220054534

# %%
# Area Under Curve
# auc = roc_auc_score(y_test, y_pred)
# auc

# %% [markdown]
# ## TASK 5

# %%
#
for i in range(0,100,10):
    X_train,X_test,y_train,y_test = train_test_split(X,
                                                     y,
                                                     test_size=.2,
                                                     random_state=i)
    model=LinearRegression()
    model.fit(X_train,y_train)
    MAE=mean_absolute_error(y_test, test_predictions)
    MSE=mean_squared_error(y_test, test_predictions)
    RMSE=np.sqrt(MSE)
    print("Random_State,MAE,MSE,RMSE:",i,MAE,MSE,RMSE)
# Out:
# Random_State,MAE,MSE,RMSE: 0 66960.05268494105 7561769757.908278 86958.43695644649
# Random_State,MAE,MSE,RMSE: 10 66766.82064560948 7703926568.13272 87772.01472071107
# Random_State,MAE,MSE,RMSE: 20 61810.12005028947 6418591195.124865 80116.11070892586
# Random_State,MAE,MSE,RMSE: 30 63498.23028493521 7151175034.428429 84564.6204652302
# Random_State,MAE,MSE,RMSE: 40 62846.49892519659 6592791268.899355 81196.00525210187
# Random_State,MAE,MSE,RMSE: 50 64582.03699133657 6853317929.1571045 82784.76870268531
# Random_State,MAE,MSE,RMSE: 60 62476.55071509129 6591015896.519983 81185.07188221233
# Random_State,MAE,MSE,RMSE: 70 59621.47659279798 5854598905.131388 76515.35078094713
# Random_State,MAE,MSE,RMSE: 80 62313.45794521054 6301617519.15321 79382.7280908965
# Random_State,MAE,MSE,RMSE: 90 69443.57783156577 7999722978.4810095 89441.17048921603

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # PART 3

# %% [markdown]
# ## TASK 1

# %%
df_subset1
# Out:
#       SalePrice  GrLivArea  LotArea  GarageArea  GarageCars  FullBath  \
# 0        208500       1710     8450         548           2         2
# 1        181500       1262     9600         460           2         2
# 2        223500       1786    11250         608           2         2
# 3        140000       1717     9550         642           3         1
# 4        250000       2198    14260         836           3         2
# ...         ...        ...      ...         ...         ...       ...
# 1455     175000       1647     7917         460           2         2
# 1456     210000       2073    13175         500           2         2
# 1457     266500       2340     9042         252           1         2
# 1458     142125       1078     9717         240           1         1
# 1459     147500       1256     9937         276           1         1
#
#       YearBuilt  YrSold  AgeWhenSold
# 0          2003    2008            5
# 1          1976    2007           31
# ...

# %%
#"GrLivArea","LotArea","GarageArea","AgeWhenSold"
X = df_subset1[["GrLivArea","LotArea","GarageArea","AgeWhenSold"]]
y = df_subset1["SalePrice"]

# %% [markdown]
# ## TASK 2

# %%
X_train,X_test,y_train,y_test = train_test_split(X,
                                                 y,
                                                 test_size=.2,
                                                 random_state=101)

# %%
X_train
# Out:
#       GrLivArea  LotArea  GarageArea  AgeWhenSold
# 796        1285     8197         528           30
# 218        1954    15660         431           69
# 1441        848     4426         420            4
# 1455       1647     7917         460            8
# 883        2230     6204         440           94
# ...         ...      ...         ...          ...
# 1017       1360     5814         565           25
# 77         1285     8635         240           60
# 628        2080    11606         504           38
# 1425       1252    10721         528           49
# 905        1063     9920         280           56
#
# [1116 rows x 4 columns]

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([  71.63025327,    1.70637201,   72.46213331, -882.36152111])

# %% [markdown]
# ## Understanding and Utilizing the model
# ##### Evaluation on the test dataset

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE=mean_absolute_error(y_test, test_predictions)
MAE
# Out:
# 30759.80998552548

# %%
MSE=mean_squared_error(y_test, test_predictions)
MSE
# Out:
# 1895721342.0373652

# %%
RMSE=np.sqrt(MSE)
RMSE
# Out:
# 43539.88220054534

# %% [markdown]
# ## TASK 3.i

# %% [markdown]
# ##### 𝑦=𝛽0+𝛽1𝑥

# %%
price_prediction = model.predict([[400,2000,80,40]])
price_prediction
# Out:
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([54742.3327449])

# %%
model.coef_
# Out:
# array([  71.63025327,    1.70637201,   72.46213331, -882.36152111])

# %%
model.intercept_
# Out:
# 52174.977586024266

# %% [markdown]
# ## TASK 3.ii

# %%
#similar properties try as ma'am!

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # PART 4

# %% [markdown]
# ## TASK 1

# %%
df_subset1
# Out:
#       SalePrice  GrLivArea  LotArea  GarageArea  GarageCars  FullBath  \
# 0        208500       1710     8450         548           2         2
# 1        181500       1262     9600         460           2         2
# 2        223500       1786    11250         608           2         2
# 3        140000       1717     9550         642           3         1
# 4        250000       2198    14260         836           3         2
# ...         ...        ...      ...         ...         ...       ...
# 1455     175000       1647     7917         460           2         2
# 1456     210000       2073    13175         500           2         2
# 1457     266500       2340     9042         252           1         2
# 1458     142125       1078     9717         240           1         1
# 1459     147500       1256     9937         276           1         1
#
#       YearBuilt  YrSold  AgeWhenSold
# 0          2003    2008            5
# 1          1976    2007           31
# ...

# %%
# shape:
df_subset1.shape
# Out:
# (1396, 9)

# %%
#description:
df_subset1.describe().T
# Out:
#               count           mean           std      min        25%  \
# SalePrice    1396.0  173694.728510  68241.162859  34900.0  128987.50
# GrLivArea    1396.0    1454.541547    427.162219    334.0    1118.00
# LotArea      1396.0    9639.573066   4198.748983   1300.0    7420.00
# GarageArea   1396.0     463.244269    208.497475      0.0     312.00
# GarageCars   1396.0       1.736390      0.734696      0.0       1.00
# FullBath     1396.0       1.534384      0.528303      0.0       1.00
# YearBuilt    1396.0    1971.280086     29.920390   1872.0    1954.00
# YrSold       1396.0    2007.820201      1.333836   2006.0    2007.00
# AgeWhenSold  1396.0      36.540115     29.969264      0.0       7.75
#
#                   50%        75%       max
# SalePrice    159467.0  205000.00  611657.0
# GrLivArea      1435.0    1726.50    2599.0
# LotArea        9301.5   11340.00   39104.0
# GarageArea      472.0     576.00    1390.0
# GarageCars        2.0       2.00       4.0
# ...

# %%
#info:
df_subset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1396 entries, 0 to 1459
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SalePrice    1396 non-null   int64
#  1   GrLivArea    1396 non-null   int64
#  2   LotArea      1396 non-null   int64
#  3   GarageArea   1396 non-null   int64
#  4   GarageCars   1396 non-null   int64
#  5   FullBath     1396 non-null   int64
#  6   YearBuilt    1396 non-null   int64
#  7   YrSold       1396 non-null   int64
#  8   AgeWhenSold  1396 non-null   int64
# dtypes: int64(9)
# memory usage: 109.1 KB

# %%
#columns:
df_subset1.columns
# Out:
# Index(['SalePrice', 'GrLivArea', 'LotArea', 'GarageArea', 'GarageCars',
#        'FullBath', 'YearBuilt', 'YrSold', 'AgeWhenSold'],
#       dtype='object')

# %%
X = df_subset1["GrLivArea"]
y = df_subset1["FullBath"]

# %%
#Creating test and training datasets:

X_train,X_test,y_train,y_test = train_test_split(X,
                                          y,
                                          test_size = 0.2,
                                          random_state=101)

# %%
print(X_train)
print(X_test)
# Out:
# 796     1285
# 218     1954
# 1441     848
# 1455    1647
# 883     2230
#         ...
# 1017    1360
# 77      1285
# 628     2080
# 1425    1252
# 905     1063
# Name: GrLivArea, Length: 1116, dtype: int64
# 792     2013
# 519     2080
# 929     2236
# 62      1370
# 1207    1700
#         ...
# 130     2157
# 513     1080
# 65      2473
# 141     1734
# 838     1099
# Name: GrLivArea, Length: 280, dtype: int64

# %%
from sklearn import preprocessing

# %%
col_encoder = preprocessing.LabelEncoder()

# %%
col_encoder.fit(df_subset1.FullBath)
print(col_encoder.classes_)
# Out:
# [0 1 2 3]

# %%
hd = df_subset1[["GrLivArea","FullBath"]]

# %%
abc = hd[(hd["FullBath"]==0)|(hd["FullBath"]==1)]
hd["Bathrooms"]=abc["FullBath"]*0
hd.replace(np.nan,1,inplace=True)
hd
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4700\1785805561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hd["Bathrooms"]=abc["FullBath"]*0
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4700\1785805561.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hd.replace(np.nan,1,inplace=True)
#       GrLivArea  FullBath  Bathrooms
# 0          1710         2        1.0
# 1          1262         2        1.0
# 2          1786         2        1.0
# 3          1717         1        0.0
# 4          2198         2        1.0
# ...

# %%
X = np.array(df_subset1['GrLivArea']).reshape(-1,1)
y = np.array(df_subset1['FullBath']).reshape(-1,1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size= 0.25, random_state = 355)

# %%
from sklearn.linear_model  import LogisticRegression

# %%
log_reg = LogisticRegression()

log_reg.fit(X_train,y_train)
# Out:
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
X=pd.DataFrame
y=pd.DataFrame
y_train=pd.DataFrame

# %% [markdown]
# Let's see how well our model performs on the test data set.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score

# %%
y_pred = log_reg.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7564469914040115

# %%
# Confusion Matrix
conf_mat = confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[122,  40,   0],
#        [ 42, 142,   0],
#        [  0,   3,   0]], dtype=int64)

# %%
# Area Under Curve
# auc = roc_auc_score(y_test, y_pred)
# auc

# %% [markdown]
# # PART 5

# %% [markdown]
# ## TASK 1

# %%
df_subset1
# Out:
#       SalePrice  GrLivArea  LotArea  GarageArea  GarageCars  FullBath  \
# 0        208500       1710     8450         548           2         2
# 1        181500       1262     9600         460           2         2
# 2        223500       1786    11250         608           2         2
# 3        140000       1717     9550         642           3         1
# 4        250000       2198    14260         836           3         2
# ...         ...        ...      ...         ...         ...       ...
# 1455     175000       1647     7917         460           2         2
# 1456     210000       2073    13175         500           2         2
# 1457     266500       2340     9042         252           1         2
# 1458     142125       1078     9717         240           1         1
# 1459     147500       1256     9937         276           1         1
#
#       YearBuilt  YrSold  AgeWhenSold
# 0          2003    2008            5
# 1          1976    2007           31
# ...

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
df_subset1["GarageCars"].unique()
# Out:
# array([2, 3, 1, 0, 4], dtype=int64)

# %%
# dfff = df_subset1[(df_subset1["GarageCars"]>0)]
# dfff

# %%
dff = df_subset1[(df_subset1["GarageCars"]!=0)]
dff
# Out:
#       SalePrice  GrLivArea  LotArea  GarageArea  GarageCars  FullBath  \
# 0        208500       1710     8450         548           2         2
# 1        181500       1262     9600         460           2         2
# 2        223500       1786    11250         608           2         2
# 3        140000       1717     9550         642           3         1
# 4        250000       2198    14260         836           3         2
# ...         ...        ...      ...         ...         ...       ...
# 1455     175000       1647     7917         460           2         2
# 1456     210000       2073    13175         500           2         2
# 1457     266500       2340     9042         252           1         2
# 1458     142125       1078     9717         240           1         1
# 1459     147500       1256     9937         276           1         1
#
#       YearBuilt  YrSold  AgeWhenSold
# 0          2003    2008            5
# 1          1976    2007           31
# ...

# %% [markdown]
# ## TASK 2

# %%
# detect correlations
column_correlation = dff.corr()
column_correlation
# Out:
#              SalePrice  GrLivArea   LotArea  GarageArea  GarageCars  FullBath  \
# SalePrice     1.000000   0.672079  0.319032    0.615951    0.640814  0.531334
# GrLivArea     0.672079   1.000000  0.331382    0.421544    0.463773  0.612238
# LotArea       0.319032   0.331382  1.000000    0.264097    0.221980  0.118636
# GarageArea    0.615951   0.421544  0.264097    1.000000    0.835227  0.397980
# GarageCars    0.640814   0.463773  0.221980    0.835227    1.000000  0.502412
# FullBath      0.531334   0.612238  0.118636    0.397980    0.502412  1.000000
# YearBuilt     0.591865   0.246867  0.015891    0.478751    0.558224  0.526695
# YrSold       -0.014629  -0.040896 -0.029916   -0.026335   -0.044965 -0.018837
# AgeWhenSold  -0.591747  -0.248415 -0.017243   -0.479322   -0.559544 -0.526857
#
#              YearBuilt    YrSold  AgeWhenSold
# SalePrice     0.591865 -0.014629    -0.591747
# GrLivArea     0.246867 -0.040896    -0.248415
# LotArea       0.015891 -0.029916    -0.017243
# ...

# %%
# sns.heatmap(column_correlation);

# plt.show()

# # white background style for seaborn plots...
# sns.set(style="white")

# sns.set(style="whitegrid",
#         color_codes=True)

# %%
X = dff[["GarageArea","YearBuilt"]]
y = dff["GarageCars"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size = .2,
                                                    random_state=101)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1053, 2), (1053,), (264, 2), (264,))

# %%
#1
# Creating Decision Tree classifer object...
dtc = DecisionTreeClassifier(max_depth=3)

# Train Decision Tree Classifer...
dtc = dtc.fit(X_train,y_train)

# Predicting the response for test dataset...
y_pred = dtc.predict(X_test)

# %%
# TEST Model Accuracy...

print("Accuracy:",
      metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8977272727272727

# %%
#2

dtc = DecisionTreeClassifier(max_depth=3)
dtc = dtc.fit(X_test,y_test)
y_pred2 = dtc.predict(X_train)

# %%
# TEST Model Accuracy...

print("Accuracy:",
      metrics.accuracy_score(y_train, y_pred2))
# Out:
# Accuracy: 0.9097815764482431

# %% [markdown]
# ## TASK 3

# %%
plt.plot(X,y,"-")
plt.xlabel("Garage Area sq.ft")
plt.ylabel("Cars Count")
plt.title("Cars v/s Garage Area")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [239], in <cell line: 1>()
# ----> 1 plt.plot(X,y,"-")
#       2 plt.xlabel("Garage Area sq.ft")
#       3 plt.ylabel("Cars Count")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
# ...
